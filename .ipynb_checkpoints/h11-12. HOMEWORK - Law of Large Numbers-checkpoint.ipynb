# %% [markdown]
# Section 2 Homework

# %% [markdown]
# Udemy video: https://www.udemy.com/python-coding/learn/v4/t/lecture/5488104?start=0

# %% [markdown]
# https://www.superdatascience.com/pages/python

# %% [markdown]
# Xn => E(X) when n => infinity

# %% [markdown]
# example 10 coin tosses : 7 heads / 3 tails 70%/30% wouldn't be abnormal
# with 100 though you'd expect things to get closer to 50/50
# at 1000 tosses even more so
# basically as you increase n you'd expect an average of the measured value would converge on the expected value
# in this case 50/50.
# This takes us to the idea of a normal distribution.

# %%
# answer to homework
import numpy as np
from numpy.random import randn
N = 10000 #designate value of N
counter = 0
for i in randn(N): # then use N
    if (i > -1 and i < 1):
        counter = counter + 1
counter/N # to get percent / by N 
# result should be close to 68%
# Out:
# 0.6745

# %%
# grabbed off google search
# basic idea is that in normal distribution 68% of values in a normal distribution will
# show between 1 standard deviation from the mean either 1 or -1

import numpy as np

# Sample from a normal distribution using numpy's random number generator
samples = np.random.normal(size=10000)

# Compute a histogram of the sample
bins = np.linspace(-5, 5, 30)
histogram, bins = np.histogram(samples, bins=bins, density=True)

bin_centers = 0.5*(bins[1:] + bins[:-1])

# Compute the PDF on the bin centers from scipy distribution object
from scipy import stats
pdf = stats.norm.pdf(bin_centers)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 4))
plt.plot(bin_centers, histogram, label="Histogram of samples")
plt.plot(bin_centers, pdf, label="PDF")
plt.legend()
plt.show()
