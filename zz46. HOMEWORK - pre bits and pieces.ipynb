# %% [markdown]
# HOMEWORK Section 5: https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P4-Section5-Homework-Challenge.pdf

# %% [markdown]
# https://www.superdatascience.com/pages/python

# %% [markdown]
# Demographic data: https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P4-Demographic-Data.csv

# %% [markdown]
# Homework dataset: https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P4-Section5-Homework-Dataset.zip

# %% [markdown]
# Fill in the blanks: https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P4-Section5-Fill-In-The-Blanks.zip

# %%
#MAC load method number 1
#data from : https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P4-Demographic-Data.csv 
#get bits and pieces in place
import numpy as np
import pandas as pd
stats = pd.read_csv('/Users/markloessi/Python/Demographic-Data.csv')
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.lmplot.html?highlight=scatter_kws

# %% [markdown]
# Inparticular we are after scatter elements https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg=False, \
                 hue='IncomeGroup', size=7, scatter_kws={"s":200}  )
